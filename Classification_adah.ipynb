# %%
# import libraries

import matplotlib.pyplot as plt 
import numpy as np 
import os
import PIL 
import tensorflow as tf 
from tensorflow import keras 
from tensorflow.keras import layers 
from tensorflow.keras.models import Sequential
import pathlib 
import pandas as pd

# %%
#read data in excel
path = "https://github.com/adah4685/patient1/blob/main/Day%201.xlsx?raw=true"
Patient1=pd.read_excel(path)
Patient1
# Out:
#         Pressure      Flow
# 0           1.96  0.327833
# 1           3.09  0.451433
# 2           6.01  0.575033
# 3           8.94  0.698067
# 4          10.56  0.684800
# ...          ...       ...
# 128244      0.00  0.000000
# 128245      0.00  0.000000
# 128246      0.00  0.000000
# 128247      0.00  0.000000
# 128248      0.00  0.000000
#
# [128249 rows x 2 columns]

# %%
cols=[0]
Pressure=pd.read_excel(path,usecols=cols)
a=Pressure
a.head(600)
# Out:
#      Pressure
# 0        1.96
# 1        3.09
# 2        6.01
# 3        8.94
# 4       10.56
# ..        ...
# 595      3.21
# 596      3.23
# 597      3.17
# 598      3.16
# 599      3.16
#
# [600 rows x 1 columns]

# %%
plt.plot(a)
plt.xlim([0, 900])
plt.show()

# %%
cols=[1]
Flow=pd.read_excel(path,usecols=cols)
b=Flow
b.head(600)
# Out:
#          Flow
# 0    0.327833
# 1    0.451433
# 2    0.575033
# 3    0.698067
# 4    0.684800
# ..        ...
# 595 -0.035333
# 596 -0.034900
# 597 -0.035967
# 598 -0.037200
# 599 -0.037100
#
# [600 rows x 1 columns]

# %%
plt.plot(b)
plt.xlim([0, 900])
plt.show()

# %%
# load a dataset group, such as train or test
def load_dataset_group(group, prefix=''):
	filepath = prefix + group + '/Inertial Signals/'
	# load all 9 files as a single array
	filenames = list()
	# total acceleration
	filenames += ['total_acc_x_'+group+'.txt', 'total_acc_y_'+group+'.txt', 'total_acc_z_'+group+'.txt']
	# body acceleration
	filenames += ['body_acc_x_'+group+'.txt', 'body_acc_y_'+group+'.txt', 'body_acc_z_'+group+'.txt']
	# body gyroscope
	filenames += ['body_gyro_x_'+group+'.txt', 'body_gyro_y_'+group+'.txt', 'body_gyro_z_'+group+'.txt']
	# load input data
	X = load_group(filenames, filepath)
	# load class output
	y = load_file(prefix + group + '/y_'+group+'.txt')
	return X, y
